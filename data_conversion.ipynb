# %%
# Import the required modules.
import os

# Paths for the data directory, text file, and compressed file.
data_directory = os.path.join('.', 'data')
if not os.path.exists(data_directory):
    print("[ERROR] data directory ('{}') does not exist".format(data_directory))

INPUT_FILE_NAME = "finefoods.txt"
OUTPUT_FILE_NAME = "finefoods.csv"

input_filepath = os.path.join(data_directory, INPUT_FILE_NAME)
csv_filepath = os.path.join(data_directory, OUTPUT_FILE_NAME)

header = [
    "product/productId",
    "review/userId",
    "review/profileName",
    "review/helpfulness",
    "review/score",
    "review/time",
    "review/summary",
    "review/text"]

simple_header = [
    "productId",
    "userId",
    "profileName",
    "helpfulness",
    "score",
    "time",
    "summary",
    "text"]

infile = open(input_filepath, "rt", encoding="Latin-1")
csvfile = open(csv_filepath, "wt", encoding="UTF-8")


# Write a list of fields as a comma-separated row with a pipe (|) as a quote character.
def write_quoted_fields(csvfile, field_list):
    csvfile.write('|' + field_list[0] + '|')
    for field in field_list[1:]:
        csvfile.write(',|' + field + '|')
    csvfile.write("\n")


# Write the header line.
write_quoted_fields(csvfile, simple_header)

# Useful controls during debugging.
record_limit = 1000000
troublesome_records = [] #370, 211557, 226163, 519217, 521382, 525958, 531539

field_count = len(header)
line_count = 0
record_count = 0
currentLine = []
for line in infile:
    #print("Processing line: {}".format(line.strip()))
    line_count += 1
    line = line.strip()

    if line == "":
        if len(currentLine) == field_count:
            write_quoted_fields(csvfile, currentLine)
            record_count += 1

            if (record_count+1) in troublesome_records:
                print("[WARN] troublesome record -1: {}".format(currentLine))

            if record_count in troublesome_records:
                print("[WARN] troublesome record: {}".format(currentLine))

            if (record_count-1) in troublesome_records:
                print("[WARN] troublesome record +1: {}".format(currentLine))

        else:
            print("[WARN] current record appears to be incomplete: {}".format(currentLine))
        
        currentLine = []
        continue

    parts = line.split(": ", 1)
    
    # Check to see if the line looks sensible enough to be added.
    if len(parts) == 2:
        # If there are pipe characters in the text (unlikely), replace them with a slash.
        field = parts[1].strip().replace('|', '/')
        currentLine.append(field)
    else:
        # Throw this away - there are junk lines in the raw file, e.g.:
        # review/profileName: Sherry "Tell us about yourself!
        # School Princi...
        print("[WARN] only found {} parts after splitting line: {}".format(len(parts), parts))
        print("[WARN] line was: {}".format(line))
        
    if record_count > record_limit:
        break


# Write the final record (if it is complete).
if len(currentLine) == field_count:
    write_quoted_fields(csvfile, currentLine)
    record_count += 1
    
# Close files.
infile.close()
csvfile.close()

print("Finished - wrote {} lines and {} records.".format(line_count, record_count))
# Out:
# [WARN] only found 1 parts after splitting line: ['88 years old. ...']
# [WARN] line was: 88 years old. ...
# [WARN] only found 1 parts after splitting line: ['...creative powers b...']
# [WARN] line was: ...creative powers b...
# [WARN] only found 1 parts after splitting line: ['School Princi...']
# [WARN] line was: School Princi...
# [WARN] only found 1 parts after splitting line: ['School Princi...']
# [WARN] line was: School Princi...
# [WARN] only found 1 parts after splitting line: ['I am a voracious reader/li...']
# [WARN] line was: I am a voracious reader/li...
# [WARN] only found 1 parts after splitting line: ['School Princi...']
# [WARN] line was: School Princi...
# [WARN] only found 1 parts after splitting line: ['...creative powers b...']
# [WARN] line was: ...creative powers b...
# Finished - wrote 5116093 lines and 568454 records.

# %%
import numpy as np
import pandas as pd
from IPython.display import display

column_dtypes = {'productId': str, 'userId': str, 'profileName': str, 'helpfulness': str,
                 'score': np.float64, 'time': np.int64, 'summary': str, 'text': str}

# For this dataset, 'quoting' must be set to QUOTE_ALL (1) and the quotechar to a pipe (|).
# The problem is that values in some 'text' fields begin with a ", but don't end with one,
# and many review texts contain commas, unbalanced quotes and apostrophes.
review_df = pd.read_table(csv_filepath, delimiter=',', encoding="UTF-8", dtype=column_dtypes, 
                          quoting=1, quotechar='|', engine="c", skip_blank_lines=True, 
                          error_bad_lines=False, warn_bad_lines=True)

# %%
display(review_df['score'].value_counts())

# Convert score to an int, since it isn't truly a float.
review_df['score'] = review_df['score'].astype(int)

# Split helpfulness into 2 columns.

display(review_df.shape)
display(review_df.describe())
display(review_df.info())
display(review_df.head(10))
# Out:
# 5.0    363122
# 4.0     80655
# 1.0     52268
# 3.0     42640
# 2.0     29769
# Name: score, dtype: int64
# (568454, 8)
#                score          time
# count  568454.000000  5.684540e+05
# mean        4.183199  1.296257e+09
# std         1.312259  4.804331e+07
# min         1.000000  9.393408e+08
# 25%         4.000000  1.271290e+09
# 50%         5.000000  1.311120e+09
# 75%         5.000000  1.332720e+09
# max         5.000000  1.351210e+09
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 8 columns):
# productId      568454 non-null object
# userId         568454 non-null object
# profileName    568438 non-null object
# helpfulness    568454 non-null object
# score          568454 non-null int32
# time           568454 non-null int64
# summary        568428 non-null object
# text           568454 non-null object
# dtypes: int32(1), int64(1), object(6)
# memory usage: 32.5+ MB
# None
#     productId          userId                      profileName helpfulness  \
# 0  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian         1/1
# 1  B00813GRG4  A1D87F6ZCVE5NK                           dll pa         0/0
# 2  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"         1/1
# 3  B000UA0QIQ  A395BORC6FGVXV                             Karl         3/3
# 4  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"         0/0
# 5  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything         0/0
# 6  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan         0/0
# 7  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams         0/0
# 8  B000E7L2R4  A1MZYO9TZK0BBI                         R. James         1/1
# 9  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed         0/0
#
#    score        time                                        summary  \
# 0      5  1303862400                          Good Quality Dog Food
# 1      1  1346976000                              Not as Advertised
# 2      4  1219017600                          "Delight" says it all
# 3      2  1307923200                                 Cough Medicine
# 4      5  1350777600                                    Great taffy
# 5      4  1342051200                                     Nice Taffy
# 6      5  1340150400  Great!  Just as good as the expensive brands!
# 7      5  1336003200                         Wonderful, tasty taffy
# 8      5  1322006400                                     Yay Barley
# 9      5  1351209600                               Healthy Dog Food
#
#                                                 text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...
# 5  I got a wild hair for taffy and ordered this f...
# 6  This saltwater taffy had great flavors and was...
# 7  This taffy is so good.  It is very soft and ch...
# 8  Right now I'm mostly just sprouting this so my...
# 9  This is a very healthy dog food. Good for thei...

# %%
review_df['helpfulness_numerator'] = [x[0] for x in review_df['helpfulness'].str.split('/')]
review_df['helpfulness_denominator'] = [x[1] for x in review_df['helpfulness'].str.split('/')]

display(review_df.head(100))
# Out:
#      productId          userId                      profileName helpfulness  \
# 0   B001E4KFG0  A3SGXH7AUHU8GW                       delmartian         1/1
# 1   B00813GRG4  A1D87F6ZCVE5NK                           dll pa         0/0
# 2   B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"         1/1
# 3   B000UA0QIQ  A395BORC6FGVXV                             Karl         3/3
# 4   B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"         0/0
# 5   B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything         0/0
# 6   B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan         0/0
# 7   B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams         0/0
# 8   B000E7L2R4  A1MZYO9TZK0BBI                         R. James         1/1
# 9   B00171APVA  A21BT40VZCCYT4                    Carol A. Reed         0/0
# 10  B0001PB9FE  A3HDKO7OW0QNK4                     Canadian Fan         1/1
# 11  B0009XLVG0  A2725IB4YY9JEB           A Poeng "SparkyGoHome"         4/4
# 12  B0009XLVG0   A327PCT23YH90                               LT         1/1
# 13  B001GVISJM  A18ECVX2RJ7HUE                  willie "roadie"         2/2
# 14  B001GVISJM  A2MUGFV2TDQ47K              Lynrie "Oh HELL no"         4/5
# 15  B001GVISJM  A1CZX3CP8IKQIJ                     Brian A. Lee         4/5
# 16  B001GVISJM  A3KLWF6WQ5BNYO                   Erica Neathery         0/0
# 17  B001GVISJM   AFKW14U97Z6QO                            Becca         0/0
# 18  B001GVISJM  A2A9X58G2GTBLP                          Wolfee1         0/0
# 19  B001GVISJM  A3IV7CL2C13K2U                             Greg         0/0
# 20  B001GVISJM  A1WO0KGLPR5PV6                         mom2emma         0/0
# 21  B001GVISJM   AZOF9E17RGZH8                   Tammy Anderson         0/0
# 22  B001GVISJM   ARYVQL4N737A1                    Charles Brown         0/0
# 23  B001GVISJM   AJ613OLZZUG7V                           Mare's         0/0
# 24  B001GVISJM  A22P2J09NJ9HKE      S. Cabanaugh "jilly pepper"         0/0
# 25  B001GVISJM  A3FONPR03H3PJS     Deborah S. Linzer "Cat Lady"         0/0
# 26  B001GVISJM  A3RXAU2N8KV45G                           lady21         0/1
# 27  B001GVISJM   AAAS38B98HMIK                     Heather Dube         0/1
# 28  B00144C10S  A2F4LZVGFLD1OB                           DaisyH         0/0
# 29  B0001PB9FY  A3HDKO7OW0QNK4                     Canadian Fan         1/1
# ..         ...             ...                              ...         ...
# 70  B001GVISJC  A27TKQHFW0FB5N                             Chet         2/2
# 71  B001GVISJC  A3BDOAPSF96WGQ                            2tall         1/1
# 72  B006SQBRMA   ATYMT48R62ENE                            Marie         0/0
# 73  B0059WXJKM  A25VFHVGI4CFTP                   Diana Robinson         0/1
# 74  B001EPPI84  A3Q0IDQ03S0158                              Jen         0/0
# 75  B001EPPI84  A27TZ4WBU7N0YF                            I. So         0/0
# 76  B004X2KR36  A2W3ABLWMJ84NS                   Jessica Snyder         0/0
# 77  B004X2KR36  A26M5O53PHZTKN                    Debs "peanut"         0/0
# 78  B004X2KR36  A2AB7M9UCNBVN7                         sharonh4         0/0
# 79  B005R8JE8O  A3H1EQD2PBC085                              jmc         0/0
# 80  B0066DMI6Y   AB30HQTI5VOLR                   Melinda Bishop         1/1
# 81  B0066DMI6Y   AZLONLC8OZPEC                   John W. Hollis         1/1
# 82  B003ZFRKGO  A2VOZX7YBT0D6D        Johnnycakes "Johnnycakes"       15/15
# 83  B0019CW0HE  A1FD9E5C06UB6B                    BRENDA DEMERS         5/5
# 84  B0019CW0HE   AK2CXHH9VRZ2A                         I. GLENN         4/4
# 85  B0019CW0HE  A25BGFRHYHEZKK                       Toby's mom         4/4
# 86  B0019CW0HE  A37N9XZBB8JYOF                            Ash52         1/1
# 87  B0019CW0HE   A1T4L0Q47OZ9N                            Wendy         1/1
# 88  B0019CW0HE  A3IMXZE9FCUNOC                             Dana         1/1
# 89  B0019CW0HE  A1EC57S6C2VLTL             Lorraine "Agelechio"         0/0
# 90  B0019CW0HE  A1OGD72Y2Y26CF                         Lisas201         0/0
# 91  B0019CW0HE   A7JWCYVPF7KCO                             gare         0/0
# 92  B0019CW0HE   ABG53EBZBKD23            J. Romagnoli "*jroma"         0/0
# 93  B0019CW0HE  A3AF72GP4GVRY1                    John D. Meara         0/0
# 94  B0019CW0HE  A1DJAAKLPCJRZD                            wendy         0/0
# 95  B0019CW0HE  A1BFNM27629VAV                        E. Triebe         0/0
# 96  B0019CW0HE  A18AAABCIJKC5Q                          Rhiever         0/0
# 97  B0019CW0HE  A3UII2114114PI               FuNky Faja "SiLkk"         0/0
# 98  B0019CW0HE   ABZ9F0D94YK45                 Amazon-tron 3000         0/0
# 99  B0019CW0HE  A2P6ACFZ8FTNVV                 Melissa Benjamin         0/1
#
#     score        time                                            summary  \
# 0       5  1303862400                              Good Quality Dog Food
# 1       1  1346976000                                  Not as Advertised
# 2       4  1219017600                              "Delight" says it all
# 3       2  1307923200                                     Cough Medicine
# 4       5  1350777600                                        Great taffy
# 5       4  1342051200                                         Nice Taffy
# 6       5  1340150400      Great!  Just as good as the expensive brands!
# 7       5  1336003200                             Wonderful, tasty taffy
# 8       5  1322006400                                         Yay Barley
# 9       5  1351209600                                   Healthy Dog Food
# 10      5  1107820800                    The Best Hot Sauce in the World
# 11      5  1282867200  My cats LOVE this "diet" food better than thei...
# 12      1  1339545600               My Cats Are Not Fans of the New Food
# 13      4  1288915200                                  fresh and greasy!
# 14      5  1268352000                       Strawberry Twizzlers - Yummy
# 15      5  1262044800           Lots of twizzlers, just what you expect.
# 16      2  1348099200                                         poor taste
# 17      5  1345075200                                           Love it!
# 18      5  1324598400                                 GREAT SWEET CANDY!
# 19      5  1318032000                            Home delivered twizlers
# 20      5  1313452800                                       Always fresh
# 21      5  1308960000                                          TWIZZLERS
# 22      5  1304899200                                 Delicious product!
# 23      5  1304467200                                          Twizzlers
# 24      5  1295481600                      Please sell these in Mexico!!
# 25      5  1288310400                             Twizzlers - Strawberry
# 26      1  1332633600                                    Nasty No flavor
# 27      4  1331856000                        Great Bargain for the Price
# 28      5  1338854400                                             YUMMY!
# 29      5  1107820800                    The Best Hot Sauce in the World
# ..    ...         ...                                                ...
# 70      5  1254355200                                       Great Gummi!
# 71      5  1289260800                           Bigger then other brands
# 72      5  1327017600                              Best ever latice tart
# 73      1  1335744000               Warning!  WARNING!  -ALCOHOL SUGARS!
# 74      2  1287705600                                    nothing special
# 75      1  1275004800                                      No Tea Flavor
# 76      5  1348444800                                               Good
# 77      5  1348185600                                        Taste great
# 78      3  1346976000                         Order only in cold weather
# 79      5  1344902400                                   this is the best
# 80      5  1325116800                                         Delicious!
# 81      4  1324598400                                              Great
# 82      5  1325635200  Forget Molecular Gastronomy - this stuff rocke...
# 83      3  1301011200                      Natural Balance Lamb and Rice
# 84      3  1313193600                          INCREASED MY DOGS ITCHING
# 85      5  1292889600                                        Great food!
# 86      5  1333670400                        Great for my dogs allergies
# 87      5  1320883200                        Great for stomach problems!
# 88      5  1311638400                           Better life for you dog!
# 89      5  1347408000                                         Great Food
# 90      5  1335398400  Great food for my my dog who has a sensitive s...
# 91      5  1334966400                                     Great dog food
# 92      5  1333929600                                 Mmmmm  Mmmmm good.
# 93      5  1330041600                                    Great Dog Food!
# 94      5  1329609600                                      So convenient
# 95      5  1320105600                              Good healthy dog food
# 96      5  1303776000                                     Great dog food
# 97      5  1297296000     Great allergy sensitive dog food, dogs love it
# 98      5  1295308800     Perfect for our English Bulldog with Allergies
# 99      1  1331164800                                                Bad
#
#                                                  text helpfulness_numerator  \
# 0   I have bought several of the Vitality canned d...                     1
# 1   Product arrived labeled as Jumbo Salted Peanut...                     0
# 2   This is a confection that has been around a fe...                     1
# 3   If you are looking for the secret ingredient i...                     3
# 4   Great taffy at a great price.  There was a wid...                     0
# 5   I got a wild hair for taffy and ordered this f...                     0
# 6   This saltwater taffy had great flavors and was...                     0
# 7   This taffy is so good.  It is very soft and ch...                     0
# 8   Right now I'm mostly just sprouting this so my...                     1
# 9   This is a very healthy dog food. Good for thei...                     0
# 10  I don't know if it's the cactus or the tequila...                     1
# 11  One of my boys needed to lose some weight and ...                     4
# 12  My cats have been happily eating Felidae Plati...                     1
# 13  good flavor! these came securely packed... the...                     2
# 14  The Strawberry Twizzlers are my guilty pleasur...                     4
# 15  My daughter loves twizzlers and this shipment ...                     4
# 16  I love eating them and they are good for watch...                     0
# 17  I am very satisfied with my Twizzler purchase....                     0
# 18  Twizzlers, Strawberry my childhood favorite ca...                     0
# 19  Candy was delivered very fast and was purchase...                     0
# 20  My husband is a Twizzlers addict.  We've bough...                     0
# 21  I bought these for my husband who is currently...                     0
# 22  I can remember buying this candy as a kid and ...                     0
# 23  I love this candy.  After weight watchers I ha...                     0
# 24  I have lived out of the US for over 7 yrs now,...                     0
# 25  Product received is as advertised.<br /><br />...                     0
# 26  The candy is just red , No flavor . Just  plan...                     0
# 27  I was so glad Amazon carried these batteries. ...                     0
# 28  I got this for my Mum who is not diabetic but ...                     0
# 29  I don't know if it's the cactus or the tequila...                     1
# ..                                                ...                   ...
# 70  These Albanese gummi bears and rings and so on...                     2
# 71  Grape gummy bears are hard to find in my area....                     1
# 72  I ordered two of these and two of raspberry la...                     0
# 73  Buyer Beware Please! This sweetener is not for...                     0
# 74  It is okay.  I would not go out of my way to b...                     0
# 75  No tea flavor at all. Just whole brunch of art...                     0
# 76  These looked like a perfect snack to through i...                     0
# 77  These taste really good. I have been purchasin...                     0
# 78  The taste was great, but the berries had melte...                     0
# 79  i know i cannot make tea this good.  granted, ...                     0
# 80  This peppermint stick is delicious and fun to ...                     1
# 81  Great gift for all ages! I purchased these gia...                     1
# 82  I know the product title says Molecular Gastro...                    15
# 83  While my dogs like all of the flavors that we ...                     5
# 84  Awesome dog food. However, when given to my "B...                     4
# 85  We have three dogs and all of them love this f...                     4
# 86  My dog has a ton of allergies both environment...                     1
# 87  My shepherd/collie mix has IBS.  Our vet recom...                     1
# 88  Natural Balance Dry Dog Food Lamb Meal and Bro...                     1
# 89  Great food! I love the idea of one food for al...                     0
# 90  I have a standard poodle and pomeranian who bo...                     0
# 91  This is great dog food, my dog has severs alle...                     0
# 92  This food is great - all ages dogs.  I have a ...                     0
# 93  My golden retriever is one of the most picky d...                     0
# 94  This is the same food we get at pet store. But...                     0
# 95  I've been very pleased with the Natural Balanc...                     0
# 96  My 1-1/2 year old basenji/jack russell mix lov...                     0
# 97  Our pup has experienced allergies in forms of ...                     0
# 98  My English Bulldog had skin allergies the summ...                     0
# 99  I fed this to my Golden Retriever and he hated...                     0
#
#    helpfulness_denominator
# 0                        1
# 1                        0
# 2                        1
# 3                        3
# 4                        0
# 5                        0
# 6                        0
# 7                        0
# 8                        1
# 9                        0
# 10                       1
# 11                       4
# 12                       1
# 13                       2
# 14                       5
# 15                       5
# 16                       0
# 17                       0
# 18                       0
# 19                       0
# 20                       0
# 21                       0
# 22                       0
# 23                       0
# 24                       0
# 25                       0
# 26                       1
# 27                       1
# 28                       0
# 29                       1
# ..                     ...
# 70                       2
# 71                       1
# 72                       0
# 73                       1
# 74                       0
# 75                       0
# 76                       0
# 77                       0
# 78                       0
# 79                       0
# 80                       1
# 81                       1
# 82                      15
# 83                       5
# 84                       4
# 85                       4
# 86                       1
# 87                       1
# 88                       1
# 89                       0
# 90                       0
# 91                       0
# 92                       0
# 93                       0
# 94                       0
# 95                       0
# 96                       0
# 97                       0
# 98                       0
# 99                       1
#
# [100 rows x 10 columns]

# %%
review_df['date'] = pd.to_datetime(review_df['time'], unit='s')

display(review_df.dtypes)
display(review_df[['productId', 'userId', 'time', 'date']].head(10))
# Out:
# productId                          object
# userId                             object
# profileName                        object
# helpfulness                        object
# score                               int32
# time                                int64
# summary                            object
# text                               object
# helpfulness_numerator              object
# helpfulness_denominator            object
# date                       datetime64[ns]
# dtype: object
#     productId          userId        time       date
# 0  B001E4KFG0  A3SGXH7AUHU8GW  1303862400 2011-04-27
# 1  B00813GRG4  A1D87F6ZCVE5NK  1346976000 2012-09-07
# 2  B000LQOCH0   ABXLMWJIXXAIN  1219017600 2008-08-18
# 3  B000UA0QIQ  A395BORC6FGVXV  1307923200 2011-06-13
# 4  B006K2ZZ7K  A1UQRSCLF8GW1T  1350777600 2012-10-21
# 5  B006K2ZZ7K   ADT0SRK1MGOEU  1342051200 2012-07-12
# 6  B006K2ZZ7K  A1SP2KVKFXXRU1  1340150400 2012-06-20
# 7  B006K2ZZ7K  A3JRGQVEQN31IQ  1336003200 2012-05-03
# 8  B000E7L2R4  A1MZYO9TZK0BBI  1322006400 2011-11-23
# 9  B00171APVA  A21BT40VZCCYT4  1351209600 2012-10-26

# %%
del review_df['helpfulness']
review_df.to_csv("data/Reviews.csv",index=False)
